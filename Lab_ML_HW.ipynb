# %% [markdown]
# Набор данных представляет из себя параметры объектов, обнаруженных наземным черенковским телескопом MAGIC. Он обнаруживает потоки частиц, выпущенных гамма-лучами, используя эффект Черенкова-Вавилова, то есть излучение, вызываемое в прозрачной среде заряженной частицей, которая движется со скоростью, превышающей фазовую скорость распространения света в этой среде.
#
#  # Title of Database: MAGIC gamma telescope data 2004
#
# Attribute information:
#
# 1.  fLength:   continuous  # major axis of ellipse [mm]
#                              = Большая ось эллипса (в мм)
# 2.  fWidth:    continuous  # minor axis of ellipse [mm]
#                              = Малая ось эллипса (в мм)
# 3.  fSize:     continuous  # 10-log of sum of content of all pixels [in #phot]
#                              = Десятичный логарифм суммы значений всех пикселей (в фотах)
# 4.  fConc:     continuous  # ratio of sum of two highest pixels over fSize  [ratio]
#                              = Соотнношение суммы двух наивысших значений пикселей с fSize (соотношение)
# 5.  fConc1:    continuous  # ratio of highest pixel over fSize  [ratio]
#                              = Соотнношение наивысшего значения пикселея с fSize (соотношение)
# 6.  fAsym:     continuous  # distance from highest pixel to center, projected onto major axis [mm]
#                              = Расстояние от пикселя с наивысшем значением до центра, спроецированное на большую ось (в мм)
# 7.  fM3Long:   continuous  # 3rd root of third moment along major axis  [mm]
#                              = Третий корень третьего момента вдоль большой оси эллипса (в мм)
# 8.  fM3Trans:  continuous  # 3rd root of third moment along minor axis  [mm]
#                              = Третий корень третьего момента вдоль малой оси эллипса (в мм)
# 9.  fAlpha:    continuous  # angle of major axis with vector to origin [deg]
#                              = Угол большой оси эллипса с вектором до начала (в градусах)
# 10.  fDist:    continuous  # distance from origin to center of ellipse [mm]
#                              = Расстояние от начала до центра эллипса (в мм)
# 11.  class:    g,h         # gamma (signal), hadron (background)
#                              = Класс объекта - сигнал или фоновый
#
#
# (a) Original owner of the database:
#
# R. K. Bock
# Major Atmospheric Gamma Imaging Cherenkov Telescope project (MAGIC)
# http://wwwmagic.mppmu.mpg.de
# rkb@mail.cern.ch
#
#
# (b) Donor:
#
# P. Savicky
# Institute of Computer Science, AS of CR
# Czech Republic
# savicky@cs.cas.cz
#
#
# (c) Date received: May 2007

# %% [markdown]
# # Домашнее задание №1

# %% [markdown]
# ## Просмотр данных

# %% [markdown]
# Импорт необходимых библиотек для построения графиков, анализа данных и операций с матрицами:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Запись данных для анализа в переменную data, вывод данных:

# %%
data = pd.read_csv('C:/downloads/magic04data.csv', sep = ',', engine = 'python') 

data
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 5       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# 6       48.2468   17.3565  3.0332  0.2529  0.1515    8.5730   38.0957
# 7       26.7897   13.7595  2.5521  0.4236  0.2174   29.6339   20.4560
# 8       96.2327   46.5165  4.1540  0.0779  0.0390  110.3550   85.0486
# 9       46.7619   15.1993  2.5786  0.3377  0.1913   24.7548   43.8771
# 10      62.7766   29.9104  3.3331  0.2475  0.1261  -33.9065   57.5848
# 11      18.8562   16.4600  2.4385  0.5282  0.2933   25.1269   -6.5401
# ...

# %% [markdown]
# Вывод данных на экран функцией print():

# %%
print(data)
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 5       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# 6       48.2468   17.3565  3.0332  0.2529  0.1515    8.5730   38.0957
# 7       26.7897   13.7595  2.5521  0.4236  0.2174   29.6339   20.4560
# 8       96.2327   46.5165  4.1540  0.0779  0.0390  110.3550   85.0486
# 9       46.7619   15.1993  2.5786  0.3377  0.1913   24.7548   43.8771
# 10      62.7766   29.9104  3.3331  0.2475  0.1261  -33.9065   57.5848
# 11      18.8562   16.4600  2.4385  0.5282  0.2933   25.1269   -6.5401
# ...

# %% [markdown]
# Вывод первых пяти строк данных:

# %%
data.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %% [markdown]
# Вывод последних пяти строк данных:

# %%
data.tail()
# Out:
#         fLength   fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 19015   21.3846  10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452   6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455  47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135  76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814  53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist class
# 19015    2.8766   2.4229  106.8258     h
# 19016   -2.9632  86.7975  247.4560     h
# 19017   -9.4662  30.2987  256.5166     h
# 19018  -63.8389  84.6874  408.3166     h
# 19019   31.4755  52.7310  272.3174     h

# %% [markdown]
# Размер данных:

# %%
print(data.shape)
# Out:
# (19020, 11)

# %% [markdown]
# Имена столбцов:

# %%
print(data.columns)
# Out:
# Index([u'fLength', u'fWidth', u'fSize', u'fConc', u'fConc1', u'fAsym',
#        u'fM3Long', u'fM3Trans', u'fAlpha', u'fDist', u'class'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=19020, step=1)

# %% [markdown]
# Вывод третьего значения столбца 'fSize':

# %%
data.at[3, 'fSize']
# Out:
# 2.3384999999999998

# %% [markdown]
# Вывод третьего значения столбца 'fSize'(обращение как к двумерному массиву):

# %%
data['fSize'][3]
# Out:
# 2.3384999999999998

# %% [markdown]
# Тип данных в стобце fSize:

# %%
data['fSize'].dtype.name
# Out:
# 'float64'

# %% [markdown]
# Тип данных третьего элемента в стобце fSize:

# %%
type(data['fSize'][3])
# Out:
# numpy.float64

# %% [markdown]
# Первые пять значений из столбцов fWidth и fConc:

# %%
data[['fWidth', 'fConc']].head()
# Out:
#      fWidth   fConc
# 0   16.0021  0.3918
# 1   11.7235  0.5303
# 2  136.0310  0.0374
# 3    9.5728  0.6147
# 4   30.9205  0.3168

# %% [markdown]
# По каждому столбцу данные о числе ячеек, среднем занчении по столбцу, среднеквадратичном отклонении,
# минимальном, максимальном значениях, а также о квартилях:

# %%
data.describe()
# Out:
#             fLength        fWidth         fSize         fConc        fConc1  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      53.250154     22.180966      2.825017      0.380327      0.214657
# std       42.364855     18.346056      0.472599      0.182813      0.110511
# min        4.283500      0.000000      1.941300      0.013100      0.000300
# 25%       24.336000     11.863800      2.477100      0.235800      0.128475
# 50%       37.147700     17.139900      2.739600      0.354150      0.196500
# 75%       70.122175     24.739475      3.101600      0.503700      0.285225
# max      334.177000    256.382000      5.323300      0.893000      0.675200
#
#               fAsym       fM3Long      fM3Trans        fAlpha         fDist
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      -4.331745     10.545545      0.249726     27.645707    193.818026
# ...

# %%
data.describe(include = 'all')
# Out:
#              fLength        fWidth         fSize         fConc        fConc1  \
# count   19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       53.250154     22.180966      2.825017      0.380327      0.214657
# std        42.364855     18.346056      0.472599      0.182813      0.110511
# min         4.283500      0.000000      1.941300      0.013100      0.000300
# 25%        24.336000     11.863800      2.477100      0.235800      0.128475
# 50%        37.147700     17.139900      2.739600      0.354150      0.196500
# 75%        70.122175     24.739475      3.101600      0.503700      0.285225
# max       334.177000    256.382000      5.323300      0.893000      0.675200
#
# ...

# %% [markdown]
# Построение диаграммы рассеяния:

# %%
from pandas.plotting import scatter_matrix 
scatter_matrix(data, alpha = .2, figsize = (10, 10))
pass

# %% [markdown]
# Построение матрицы корреляций:

# %%
data.corr()
# Out:
#            fLength    fWidth     fSize     fConc    fConc1     fAsym  \
# fLength   1.000000  0.770512  0.702454 -0.630999 -0.598145 -0.368556
# fWidth    0.770512  1.000000  0.717517 -0.609779 -0.581141 -0.266961
# fSize     0.702454  0.717517  1.000000 -0.850850 -0.808835 -0.159863
# fConc    -0.630999 -0.609779 -0.850850  1.000000  0.976412  0.112272
# fConc1   -0.598145 -0.581141 -0.808835  0.976412  1.000000  0.100159
# fAsym    -0.368556 -0.266961 -0.159863  0.112272  0.100159  1.000000
# fM3Long  -0.119747 -0.176234  0.095157 -0.121899 -0.118769  0.274045
# fM3Trans  0.013389  0.039744  0.015455 -0.011294 -0.010966  0.002553
# fAlpha   -0.008777  0.066061 -0.186675  0.235272  0.229799 -0.055689
# fDist     0.418466  0.336816  0.437041 -0.328332 -0.304625 -0.206730
#
#            fM3Long  fM3Trans    fAlpha     fDist
# fLength  -0.119747  0.013389 -0.008777  0.418466
# fWidth   -0.176234  0.039744  0.066061  0.336816
# fSize     0.095157  0.015455 -0.186675  0.437041
# ...

# %% [markdown]
# Видна корреляция между параметром fSize объекта (яркостью звезды?) и его разметами fLength и fWidth. Также сильно кореллируют fConc и fConc1.

# %% [markdown]
# Построение графика зависимости десятичного логарифма суммы значений всех пикселей от размера малой оси эллипса:

# %%
plt.plot(data['fSize'], data['fWidth'], 'o', alpha = 0.15)
plt.xlabel('fSize')
plt.ylabel('fWidth')
plt.title('fSize / fWidth')
pass

# %% [markdown]
# Проверка превышения парамтром расстояния значения 200:

# %%
data['fDist'] >= 200
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9        False
# 10        True
# 11       False
# 12       False
# 13       False
# 14        True
# 15        True
# 16       False
# 17       False
# 18       False
# 19        True
# 20        True
# 21        True
# 22        True
# 23       False
# 24        True
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18990    False
# 18991    False
# 18992     True
# 18993    False
# 18994     True
# 18995     True
# 18996     True
# 18997    False
# 18998     True
# 18999     True
# 19000     True
# 19001    False
# 19002     True
# 19003     True
# 19004     True
# 19005    False
# 19006     True
# 19007     True
# 19008     True
# 19009    False
# 19010    False
# 19011     True
# 19012    False
# 19013     True
# 19014     True
# 19015    False
# 19016     True
# ...

# %% [markdown]
# Зависимость fSize от fConc для разных классов сигнала:

# %%
plt.figure(figsize = (10, 10))

plt.scatter(data[data['class'] == 'g']['fSize'],
            data[data['class'] == 'g']['fConc'],
            alpha = 0.15,
            label = 'g',
            color = 'b')

plt.scatter(data[data['class'] == 'h']['fSize'],
            data[data['class'] == 'h']['fConc'],
            alpha = 0.15,
            label = 'h',
            color = 'r')

plt.xlabel('fSize')
plt.xlim(1.8, 5.4)
plt.ylabel('fConc')
plt.title('fSize / fConc')
plt.legend()
plt.grid()

# %% [markdown]
# Проверка существования объектов с одинаковым параметром fSize:

# %%
data['fSize'].unique().shape
# Out:
# (7228L,)

# %%
data['fSize'].shape
# Out:
# (19020L,)

# %% [markdown]
# 7228 != 19020 => такие объекты существуют.

# %% [markdown]
# Проверка наличия пропущенных значений

# %%
data.count(axis = 0)
# Out:
# fLength     19020
# fWidth      19020
# fSize       19020
# fConc       19020
# fConc1      19020
# fAsym       19020
# fM3Long     19020
# fM3Trans    19020
# fAlpha      19020
# fDist       19020
# class       19020
# dtype: int64

# %% [markdown]
# Отсюда следует, что пропущенные значения отсутствуют.

# %% [markdown]
# ## Подготовка данных
# Из приведённого описания данных видно, что один признак качественный и при том бинарный - class(g,h), а остальные - количественные, т. к. представляют карактеристики объектов в миллиметрах, градусах, фотах или соотношение характеристик.

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['class']
# ['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist']

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-25-e71fac4eacd2> in <module>()
# ----> 1 binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
#       2 nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
#       3 print(binary_columns, nonbinary_columns)
#
# NameError: name 'data_describe' is not defined

# %% [markdown]
# ### Векторизация

# %%
data_binary = data['class']
#data_binary = pd.get_dummies(data['class'])
#print(data_binary.columns)

# %%
#data.at[data['class'] == 'g', 'class'] = 0
#data.at[data['class'] == 'h', 'class'] = 1
#data['class'].describe()

# %% [markdown]
# ### Нормализация количественных признаков

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#             fLength        fWidth         fSize         fConc        fConc1  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      53.250154     22.180966      2.825017      0.380327      0.214657
# std       42.364855     18.346056      0.472599      0.182813      0.110511
# min        4.283500      0.000000      1.941300      0.013100      0.000300
# 25%       24.336000     11.863800      2.477100      0.235800      0.128475
# 50%       37.147700     17.139900      2.739600      0.354150      0.196500
# 75%       70.122175     24.739475      3.101600      0.503700      0.285225
# max      334.177000    256.382000      5.323300      0.893000      0.675200
#
#               fAsym       fM3Long      fM3Trans        fAlpha         fDist
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      -4.331745     10.545545      0.249726     27.645707    193.818026
# ...

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)
data_numerical.describe()
# Out:
#             fLength        fWidth         fSize         fConc        fConc1  \
# count  1.902000e+04  1.902000e+04  1.902000e+04  1.902000e+04  1.902000e+04
# mean  -4.444254e-15  3.960192e-15  7.620660e-15  1.456527e-14  2.884694e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.155832e+00 -1.209032e+00 -1.869910e+00 -2.008756e+00 -1.939694e+00
# 25%   -6.825033e-01 -5.623643e-01 -7.361785e-01 -7.905726e-01 -7.798526e-01
# 50%   -3.800899e-01 -2.747766e-01 -1.807389e-01 -1.431903e-01 -1.643019e-01
# 75%    3.982551e-01  1.394582e-01  5.852387e-01  6.748581e-01  6.385608e-01
# max    6.631130e+00  1.276574e+01  5.286268e+00  2.804355e+00  4.167401e+00
#
#               fAsym       fM3Long      fM3Trans        fAlpha         fDist
# count  1.902000e+04  1.902000e+04  1.902000e+04  1.902000e+04  1.902000e+04
# mean  -5.517260e-17 -1.150009e-15  3.948238e-17 -2.786345e-15 -8.689976e-16
# ...

# %% [markdown]
# ### Создание единой таблицы

# %%
data = pd.concat((data_numerical, data_binary), axis = 1)
print(data.shape)
# Out:
# (19020, 11)

# %%
data.describe()
# Out:
#             fLength        fWidth         fSize         fConc        fConc1  \
# count  1.902000e+04  1.902000e+04  1.902000e+04  1.902000e+04  1.902000e+04
# mean  -4.444254e-15  3.960192e-15  7.620660e-15  1.456527e-14  2.884694e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.155832e+00 -1.209032e+00 -1.869910e+00 -2.008756e+00 -1.939694e+00
# 25%   -6.825033e-01 -5.623643e-01 -7.361785e-01 -7.905726e-01 -7.798526e-01
# 50%   -3.800899e-01 -2.747766e-01 -1.807389e-01 -1.431903e-01 -1.643019e-01
# 75%    3.982551e-01  1.394582e-01  5.852387e-01  6.748581e-01  6.385608e-01
# max    6.631130e+00  1.276574e+01  5.286268e+00  2.804355e+00  4.167401e+00
#
#               fAsym       fM3Long      fM3Trans        fAlpha         fDist
# count  1.902000e+04  1.902000e+04  1.902000e+04  1.902000e+04  1.902000e+04
# mean  -5.517260e-17 -1.150009e-15  3.948238e-17 -2.786345e-15 -8.689976e-16
# ...

# %% [markdown]
# Вывод новой таблицы данных:

# %%
data
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 0     -0.577211 -0.336795 -0.381120  0.062758 -0.148919  0.541028  0.224812
# 1     -0.510955 -0.570012 -0.648578  0.820362  1.471737  0.516906  0.260357
# 2      2.568210  6.205695  2.615714 -1.875834 -1.773194  2.044938 -1.478497
# 3     -0.694749 -0.687241 -1.029451  1.282035  1.606566  0.532757 -0.333506
# 4      0.516609  0.476371  0.711138 -0.347497 -0.284652 -0.020200  0.353077
# 5     -0.038385 -0.056185  0.176647 -0.756658 -0.729857  0.932469  0.640060
# 6     -0.118102 -0.262970  0.440507 -0.697035 -0.571502  0.217963  0.540198
# 7     -0.624585 -0.459034 -0.577481  0.236706  0.024820  0.573685  0.194322
# 8      1.014580  1.326472  2.812075 -1.654296 -1.589502  1.937078  1.460841
# 9     -0.153152 -0.380554 -0.521409 -0.233173 -0.211356  0.491276  0.653558
# 10     0.224867  0.421313  1.075084 -0.726573 -0.801344 -0.499522  0.922336
# ...

# %% [markdown]
# ## X и y

# %%
X = data.drop(('class'), axis = 1) # выбрасываем столбец 'class'
y = data['class']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index([u'fLength', u'fWidth', u'fSize', u'fConc', u'fConc1', u'fAsym',
#        u'fM3Long', u'fM3Trans', u'fAlpha', u'fDist'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (19020, 10)
# (19020L,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# (13314, 5706)

# %%
13314+5706
# Out:
# 19020

# %% [markdown]
# Значения, известные из описания данных:
#
# Class Distribution:
# g = gamma (signal):     12332
# h = hadron (background): 6688

# %% [markdown]
# ## Метод к-ближайших соседей
#
# Выбор параметр равный 10:

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %% [markdown]
# Классификация и подсчёт ошибки:

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# (0.14773922187171398, 0.16579039607430773)

# %% [markdown]
# Другой способ подсчёта ошибки:

# %%
err_test = 1 - knn.score(X_test, y_test)

# %%
err_test
# Out:
# 0.16579039607430779

# %% [markdown]
# Построение матрицы неточностей:

# %% [markdown]
# Построение матрицы, визуализирующей прогонозы классификатора:

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[3571  134]
#  [ 812 1189]]

# %% [markdown]
# Элемент матрицы (i, j) равен числу объектов, которые, принадлежат группе i, но, по прогнозам, находятся в группе j.

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %% [markdown]
# ### Подбор параметра
# Минимизируем ошибку, подобрав значение параметра:

# %%
# Долго!
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# (0.16388763707375698, 5)

# %% [markdown]
# Вычислим значение ошибки с найденным параметром:

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# (0.11732011416554003, 0.16579039607430773)

# %% [markdown]
# Тренировочная ошибка уменьшилась, тестовая осталась такой же. Ошибка определения принадлежности объекта к классу (сигнал или фоновый) составляет ~0.166.

# %% [markdown]
# # Домашнее задание №4
#
# 15.11.17 - Исправил графики.

# %% [markdown]
# ## Обучение полносвязной (неглубокой нейросети)

# %% [markdown]
# Разбиваем данные на обучающую и тестовую выборки:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape

# %% [markdown]
# Обучаем классификатор.

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %% [markdown]
# Проверяем качество классификатора:

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %% [markdown]
# Ошибки на обучающей и тестовой выборках:

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# (0.12336184571921839, 0.12187350645212681)

# %% [markdown]
# ### Нейронная сеть с одним скрытым слоем
# Найдём значение ошибки для разного количества нейронов.

# %% [markdown]
# Построим график зависимости ошибки от числа нейронов для нейронной сети с одним скрытым слоем.

# %%
# Долго!
neurs_arr_1 = np.arange(1, 100, 1)
test_err = []
train_err = []
for neurs in neurs_arr_1:
    mlp_model = MLPClassifier(hidden_layer_sizes = (neurs,), solver = 'lbfgs',
                              activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %% [markdown]
# Минимальная ошибка:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# (0.11347406419210547, 0.11581965907280548)

# %% [markdown]
# Оптимальное количество нейронов:

# %%
neurs_opt_1 = neurs_arr_1[test_err == min_test_err][0]
print(neurs_opt_1)
# Out:
# 20

# %% [markdown]
# Построим график зависимости ошибки от числа нейронов для нейронной сети с одним скрытым слоем:

# %%
plt.figure(figsize = (15, 7))
plt.plot(neurs_arr_1, train_err, 'b', label = 'Train error')
plt.plot(neurs_arr_1, test_err, 'r', label = 'Test error')
plt.xlim([np.min(neurs_arr_1), np.max(neurs_arr_1)])
plt.title('Error/number of neurons')
plt.xlabel('number of neurons')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Для небольшого (<15) количества нейронов наблюдается недообучение.

# %% [markdown]
# ### Нейронная сеть с двумя скрытыми слоями
# Найдём значение ошибки для разного количества нейронов(число нейронов на слоях одинаковое).

# %%
# Долго!
neurs_arr_2 = np.arange(1, 100, 1)
test_err = []
train_err = []
for neurs in neurs_arr_2:
    mlp_model = MLPClassifier(hidden_layer_sizes = (neurs, neurs), solver = 'lbfgs',
                              activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %% [markdown]
# Минимальная ошибка:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# (0.10892254571137094, 0.11374860602198503)

# %% [markdown]
# Оптимальное количество нейронов:

# %%
neurs_opt_2 = neurs_arr_2[test_err == min_test_err][0]
print(neurs_opt_2)
# Out:
# 13

# %% [markdown]
# Построим график зависимости ошибки от числа нейронов для нейронной сети с двумя скрытыми слоями:

# %%
plt.figure(figsize = (15, 7))
plt.plot(neurs_arr_2, train_err, 'b', label = 'Train error')
plt.plot(neurs_arr_2, test_err, 'r', label = 'Test error')
plt.xlim([np.min(neurs_arr_2), np.max(neurs_arr_2)])
plt.title('Error/number of neurons')
plt.xlabel('number of neurons')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Для небольшого (<15) количества нейронов наблюдается недообучение. После 50 нейронов ошибки медленно возрастают.

# %% [markdown]
# ### Подбор гиперпараметров
# Для наилучшего из полученных результатов(2 слоя с 13 нейронами) подберем оптимальное значение параметра регуляризации alpha.

# %%
# Долго!
alpha_arr = np.logspace(-4, -2, 100)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (neurs_opt_2,neurs_opt_2), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.figure(figsize = (15, 5))
plt.semilogx(alpha_arr, train_err, 'b', label = 'Train error')
plt.semilogx(alpha_arr, test_err, 'r', label = 'Test error')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error/alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# (0.11316016636584791, 0.11327067070256491)

# %% [markdown]
# Оптимальное значение alpha:

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
# Out:
# [ 0.00021049  0.00022051  0.00050941]

# %%
alpha_opt = alpha_opt[0]

# %% [markdown]
# ## Классификатор при найденном оптимальном значении alpha:
# Повторим обучение:

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neurs_opt_2,neurs_opt_2),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.11488660441
# 0.113270670703

# %% [markdown]
# ### Матрица рассогласования:

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test_pred, y_test))
# Out:
# [[3836  492]
#  [ 219 1730]]

# %% [markdown]
# Элемент матрицы (i, j) равен числу объектов, которые, принадлежат группе i, но, по прогнозам, находятся в группе j.

# %%
M = confusion_matrix(y_test_pred, y_test)
M = np.sqrt(M)
plt.imshow(M, interpolation = 'nearest')
plt.set_cmap('binary')
plt.xticks(range(2))
plt.yticks(range(2))
plt.xlabel("true label")
plt.ylabel("predicted label")
plt.colorbar()
pass

# %% [markdown]
# ### Другие метрики качества:

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#              precision    recall  f1-score   support
#
#           g       0.89      0.95      0.92      4055
#           h       0.89      0.78      0.83      2222
#
# avg / total       0.89      0.89      0.88      6277

# %% [markdown]
# Использовав нейросеть с двумя скрытыми слоями с 13 нейронами удалось уменьшить значение ошибки с ~0.166 (для метода k-ближайших соседей) до ~0.113.

# %% [markdown]
# # Домашнее задание №5

# %% [markdown]
# ## Random forests

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Долго!
randTree_arr_1 = np.arange(1, 200, 1) # Проверял для большего количества деревьев, значение ошибки на тестовой выборке не уменьшается
test_err = []
train_err = []
oob_err =[]
for trees in randTree_arr_1:
    tree_model = RandomForestClassifier(n_estimators=trees, oob_score=True, random_state=42)
    tree_model.fit(X_train, y_train)

    y_train_pred = tree_model.predict(X_train)
    y_test_pred = tree_model.predict(X_test)
    oob_error = 1 - tree_model.oob_score_
    
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    oob_err.append(oob_error)
# Out:
# C:\Users\anton\Anaconda2\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\anton\Anaconda2\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %% [markdown]
# Минимальная ошибка:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# (0.0, 0.11454516488768519)

# %% [markdown]
# Оптимальное количество деревьев:

# %%
trees_opt_1 = randTree_arr_1[test_err == min_test_err][0]
print(trees_opt_1)
# Out:
# 164

# %% [markdown]
# График зависимости ошибки на обучающей и тестовой выборке и oob-ошибки от числа деревьев:

# %%
plt.figure(figsize = (15, 3))
plt.plot(randTree_arr_1, train_err, 'b', label = 'Train  error')
plt.plot(randTree_arr_1, test_err, 'r', label = 'Test  error')
plt.plot(randTree_arr_1,  oob_err, 'g', label = 'oob-error')
plt.xlim([np.min(randTree_arr_1), np.max(randTree_arr_1)])
plt.title('Error/number of trees')
plt.xlabel('number of trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Недообучение и переобучение не наблюдаются. С ростом параметра значения ошибок практически не изменяются.

# %% [markdown]
# ## Extremely random forests

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
# Долго!
randTree_arr_2 = np.arange(1, 200, 1) # Проверял до 400, значение ошибки на тестовой выборке не уменьшается
test_err = []
train_err = []
oob_err =[]
for trees in randTree_arr_2:
    tree_model = ExtraTreesClassifier(n_estimators=trees, oob_score=True, bootstrap=True, random_state=42)
    tree_model.fit(X_train, y_train)

    y_train_pred = tree_model.predict(X_train)
    y_test_pred = tree_model.predict(X_test)
    oob_error = 1 - tree_model.oob_score_
    
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    oob_err.append(oob_error)

# %% [markdown]
# Минимальная ошибка:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# (0.0, 0.11406722956826509)

# %% [markdown]
# Оптимальное количество деревьев:

# %%
trees_opt_2 = randTree_arr_2[test_err == min_test_err][0]
print(trees_opt_2)
# Out:
# 149

# %% [markdown]
# График зависимости ошибки на обучающей и тестовой выборке и oob-ошибки от числа деревьев:

# %%
plt.figure(figsize = (15, 5))
plt.plot(randTree_arr_2, train_err, 'b', label = 'Train error')
plt.plot(randTree_arr_2, test_err, 'r', label = 'Test error')
plt.plot(randTree_arr_2,  oob_err, 'g', label = 'oob-error')
plt.xlim([np.min(randTree_arr_2), np.max(randTree_arr_2)])
plt.title('Error/number of trees')
plt.xlabel('number of trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Недообучение и переобучение не наблюдаются. С ростом параметра значения ошибок практически не изменяются.

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
# Долго!
adaboost_arr = np.arange(1, 250, 1)
test_err = []
train_err = []
for nEst in adaboost_arr:
    aboost_model = AdaBoostClassifier(n_estimators=nEst, random_state=42)
    aboost_model.fit(X_train, y_train)

    y_train_pred = aboost_model.predict(X_train)
    y_test_pred = aboost_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %% [markdown]
# Минимальная ошибка:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# (0.13921368594522482, 0.14146885454835112)

# %% [markdown]
# Оптимальное значение параметра n_estimators:

# %%
nEst_opt_1 = adaboost_arr[test_err == min_test_err][0]
print(nEst_opt_1)
# Out:
# 160

# %% [markdown]
# График зависимости ошибки от параметра n_estimators:

# %%
plt.figure(figsize = (15, 5))
plt.plot(adaboost_arr, train_err, 'b', label = 'Train error')
plt.plot(adaboost_arr, test_err, 'r', label = 'Test error')
plt.xlim([np.min(adaboost_arr), np.max(adaboost_arr)])
plt.title('Error/n_estimators')
plt.xlabel('n_estimators')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Для значения параметра менее 65 наблюдается недообучение(на интервале от 35 до 50 заметнее всего). При приближении параметра n_estimators к 200 наблюдается переобучение.

# %% [markdown]
# ## Gradient boosted trees

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Долго!
grBoost_arr = np.arange(1, 200, 1) # Проверял до 800, до ~560 значение ошибки на тестовой выборке уменьшается (очень медленно)
test_err = []
train_err = []
oob_err =[]
for nEst in grBoost_arr:
    boost_model = GradientBoostingClassifier(n_estimators=nEst,random_state=42)
    boost_model.fit(X_train, y_train)

    y_train_pred = boost_model.predict(X_train)
    y_test_pred = boost_model.predict(X_test)

    
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %% [markdown]
# Минимальная ошибка:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# (0.10350780820842816, 0.12012107694758643)

# %% [markdown]
# Оптимальное значение параметра n_estimators:

# %%
nEst_opt_2 = grBoost_arr[test_err == min_test_err][0]
print(nEst_opt_2)
# Out:
# 197

# %% [markdown]
# График зависимости ошибки от параметра n_estimators:

# %%
plt.figure(figsize = (15, 5))
plt.plot(grBoost_arr, train_err, 'b', label = 'Train error')
plt.plot(grBoost_arr, test_err, 'r', label = 'Test error')
plt.xlim([np.min(grBoost_arr), np.max(grBoost_arr)])
plt.title('Error/n_estimators')
plt.xlabel('n_estimators')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Для значения параметра n_estimators менее 30 наблюдается недообучение. С ростом параметра значение ошибки на обучающей выборке уменьшается, значение ошибки на обучающей выборке уменьшается очень медленно(~0.1182 на значении 554), после значения параметра 554 эта ошибка начинает так же медленно нарастать. (Замечание: я оставил график для значения от 1 до 200, так как его вид фактически не изменяется)

# %% [markdown]
# Методы Random forests и Extremely random forests дали близкие значения ошибки на тестовой выборке (~0.1145 и ~0.1141 соответственно). Матод Gradient boosted trees дал несколько большую ошибку(~0.1182). Для метода Adaboost значение ошибки на тестовой выборке ещё выше (~0.1415). На данный момент наименьшая ошибка достигнута на полносвязной нейронной сети с двумя скрытыми слоями по 13 нейронов на каждом с параметром alfa=0.00021049 (~0.1133)
